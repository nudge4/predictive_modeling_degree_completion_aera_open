# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.metrics import precision_recall_curve, roc_auc_score, confusion_matrix, precision_score, recall_score
from sklearn.model_selection import KFold, StratifiedKFold
from scipy.stats.mstats import gmean
import xgboost as xgb
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
fpath = "/Users/ys8mz/Box Sync/Predictive Models of College Completion (VCCS)/intermediate_files"

# %%
df = pd.read_stata(fpath + "/full_data_truncated.dta")

# %%
# Exclude NSC predictors
nsc_predictors = ['pre_num_nsc_coll', 'num_nsc_coll', 'pre_nsc_terms', 'nsc_terms', 
                  'enrolled_nsc','admrate','gradrate','satvr25','satvr75','satmt25', 'satmt75','satwr25','satwr75',
                  'nsc_coll_type_1', 'nsc_coll_type_2', 'nsc_coll_type_3', 'nsc_coll_type_4',
                  'nsc_coll_type_5','nsc_coll_type_6','nsc_coll_type_7', 'nsc_coll_type_8'] + \
                 [e1+e2+str(e3) for e1 in ['enrolled_nsc_', 'enrl_intensity_nsc_'] for e2 in ['fa','su','sp'] for e3 in range(1,7)]
predictors = np.setdiff1d(list(df.columns.values)[10:], nsc_predictors)
print(len(predictors))
# Out:
# 274

# %%
impute_list_1 = set(["prop_comp_pre","cum_gpa_pre"])
impute_list_2 = set([t1+"_"+t2+str(t3) for t1 in ["term_gpa", "prop_comp", "lvl2_prop_comp", "dev_prop_comp"] for t2 in ["fa", "sp", "su"] for t3 in range(1,7,1)])
impute_list_3 = set(["cum_gpa", "lvl2_prop_comp", "dev_prop_comp", "prop_comp", "prop_comp_sd", "withdrawn_prop_comp_sd"])
impute_list_4 = set(["admrate", "gradrate", "satvr25", "satvr75", "satmt25", "satmt75", "satwr25", "satwr75"])

# %%
train_df = df[df.valid == 0]
test_df = df[df.valid == 1]
print(train_df.shape,test_df.shape)
# Out:
# (298139, 341) (33115, 341)

# %%
def impute(train, test):
    for p in impute_list_1:
        avg_p = np.nanmean(train[train.enrolled_pre == 1][p])
        train.loc[:,p] = train.loc[:,p].apply(lambda x: avg_p if pd.isnull(x) else x)
        test.loc[:,p] = test.loc[:,p].apply(lambda x: avg_p if pd.isnull(x) else x)
    for p in impute_list_3:
        avg_p = np.nanmean(train[p])
        train.loc[:,p] = train.loc[:,p].apply(lambda x: avg_p if pd.isnull(x) else x)
        test.loc[:,p] = test.loc[:,p].apply(lambda x: avg_p if pd.isnull(x) else x)
    for p in impute_list_2:
        suffix = p[-3:]
        avg_p = np.nanmean(train[train["enrolled_" + suffix] == 1][p])
        train.loc[:,p] = train.loc[:,p].apply(lambda x: avg_p if pd.isnull(x) else x)
        test.loc[:,p] = test.loc[:,p].apply(lambda x: avg_p if pd.isnull(x) else x)
    for p in impute_list_4:
        avg_p = np.nanmean(train[train["enrolled_nsc"] == 1][p])
        train.loc[:,p] = train.loc[:,p].apply(lambda x: avg_p if pd.isnull(x) else x)
        test.loc[:,p] = test.loc[:,p].apply(lambda x: avg_p if pd.isnull(x) else x)
    return train, test

# %%
train_df_new, test_df_new = impute(train_df, test_df)
X_train = train_df_new.loc[:,predictors]
y_train = train_df_new.grad_6years
X_test = test_df_new.loc[:,predictors]
y_test = test_df_new.grad_6years
# Out:
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
dtrain = xgb.DMatrix(X_train, y_train)
dtest = xgb.DMatrix(X_test, y_test)

# %%
np.random.seed(4321)
val_indices = np.random.choice(train_df.shape[0], int(np.floor(train_df.shape[0]*0.15)), replace=False)
train_val = train_df.iloc[val_indices,:]
train_train = train_df.iloc[np.setdiff1d(np.arange(train_df.shape[0]), val_indices),:]
train_train_new, train_val_new = impute(train_train, train_val)
X_train_train = train_train_new.loc[:,predictors]
y_train_train = train_train_new.grad_6years
X_train_val = train_val_new.loc[:,predictors]
y_train_val = train_val_new.grad_6years
# Out:
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
dtrain_train = xgb.DMatrix(X_train_train, y_train_train)
dtrain_val = xgb.DMatrix(X_train_val, y_train_val)

# %%
results_dir = "C:\\Users\\ys8mz\\Box Sync\\Predictive Models of College Completion (VCCS)\\evaluation_results\\truncated_new_2\\"

# %% [markdown]
# #### (1) Grid Search for max_depth and eta (learning rate)

# %%
grid_1 = [(md,e) for md in range(4,8) for e in [0.01, 0.02, 0.05, 0.1, 0.2]]
validation_auc_1 = Counter()
for md,e in grid_1:
    print("max_depth = {0}, eta = {1}:".format(md,e))
    params = {'max_depth': md, 'eta': e, 'min_child_weight': 1, 'colsample_bytree': 0.8, 
              'subsample': 0.8, 
              'objective': 'binary:logistic', 'eval_metric': ['auc'],
              'seed': 12345}
    evals_result = {}
    xgb_model = xgb.train(params = params, dtrain = dtrain_train, num_boost_round = int(5e3), evals = [(dtrain_val, 'validation')],
                          early_stopping_rounds = 10,
                          evals_result = evals_result,
                          verbose_eval = 50)
    validation_auc_1[(md,e)] = np.max(evals_result['validation']['auc'])
    print("")
# Out:
# max_depth = 4, eta = 0.01:
# [0]	validation-auc:0.808973
# Will train until validation-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [29]	validation-auc:0.841674
#
#
# max_depth = 4, eta = 0.02:
# [0]	validation-auc:0.808973
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.847543
# [100]	validation-auc:0.856022
# [150]	validation-auc:0.861742
# [200]	validation-auc:0.865906
# [250]	validation-auc:0.868731
# [300]	validation-auc:0.870938
# [350]	validation-auc:0.872702
# [400]	validation-auc:0.874201
# [450]	validation-auc:0.875398
# [500]	validation-auc:0.8764
# [550]	validation-auc:0.877206
# [600]	validation-auc:0.877867
# [650]	validation-auc:0.878525
# [700]	validation-auc:0.879079
# [750]	validation-auc:0.879589
# [800]	validation-auc:0.880068
# [850]	validation-auc:0.88057
# [900]	validation-auc:0.880993
# [950]	validation-auc:0.881369
# [1000]	validation-auc:0.881725
# [1050]	validation-auc:0.881992
# [1100]	validation-auc:0.882315
# [1150]	validation-auc:0.88266
# [1200]	validation-auc:0.882928
# [1250]	validation-auc:0.883204
# [1300]	validation-auc:0.883436
# [1350]	validation-auc:0.883623
# [1400]	validation-auc:0.883842
# [1450]	validation-auc:0.884038
# [1500]	validation-auc:0.884207
# [1550]	validation-auc:0.884392
# [1600]	validation-auc:0.884536
# [1650]	validation-auc:0.884674
# [1700]	validation-auc:0.884829
# [1750]	validation-auc:0.884946
# [1800]	validation-auc:0.885091
# [1850]	validation-auc:0.88521
# [1900]	validation-auc:0.885333
# [1950]	validation-auc:0.885445
# [2000]	validation-auc:0.885527
# [2050]	validation-auc:0.885633
# [2100]	validation-auc:0.885774
# [2150]	validation-auc:0.885883
# [2200]	validation-auc:0.885979
# [2250]	validation-auc:0.886069
# [2300]	validation-auc:0.886175
# [2350]	validation-auc:0.886279
# [2400]	validation-auc:0.886356
# Stopping. Best iteration:
# [2422]	validation-auc:0.886381
#
#
# max_depth = 4, eta = 0.05:
# [0]	validation-auc:0.808973
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.859034
# [100]	validation-auc:0.868729
# [150]	validation-auc:0.873509
# [200]	validation-auc:0.876445
# [250]	validation-auc:0.878121
# [300]	validation-auc:0.879465
# [350]	validation-auc:0.880592
# [400]	validation-auc:0.881519
# [450]	validation-auc:0.882304
# [500]	validation-auc:0.883026
# [550]	validation-auc:0.883601
# [600]	validation-auc:0.883958
# [650]	validation-auc:0.884423
# [700]	validation-auc:0.8848
# [750]	validation-auc:0.885047
# [800]	validation-auc:0.885414
# [850]	validation-auc:0.885675
# [900]	validation-auc:0.885924
# [950]	validation-auc:0.886113
# [1000]	validation-auc:0.886315
# [1050]	validation-auc:0.88649
# Stopping. Best iteration:
# [1050]	validation-auc:0.88649
#
#
# max_depth = 4, eta = 0.1:
# [0]	validation-auc:0.808973
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.868629
# [100]	validation-auc:0.87607
# [150]	validation-auc:0.879172
# [200]	validation-auc:0.881158
# [250]	validation-auc:0.882399
# [300]	validation-auc:0.883434
# [350]	validation-auc:0.884227
# [400]	validation-auc:0.884855
# [450]	validation-auc:0.885401
# [500]	validation-auc:0.885803
# [550]	validation-auc:0.886047
# [600]	validation-auc:0.886213
# [650]	validation-auc:0.88643
# Stopping. Best iteration:
# [675]	validation-auc:0.886597
#
#
# max_depth = 4, eta = 0.2:
# [0]	validation-auc:0.808973
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.875767
# [100]	validation-auc:0.881031
# [150]	validation-auc:0.883508
# [200]	validation-auc:0.884573
# [250]	validation-auc:0.885098
# [300]	validation-auc:0.885615
# Stopping. Best iteration:
# [319]	validation-auc:0.885982
#
#
# max_depth = 5, eta = 0.01:
# [0]	validation-auc:0.821264
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.85042
# [100]	validation-auc:0.854797
# [150]	validation-auc:0.858962
# [200]	validation-auc:0.862019
# [250]	validation-auc:0.864638
# [300]	validation-auc:0.866894
# [350]	validation-auc:0.868971
# [400]	validation-auc:0.870679
# [450]	validation-auc:0.872162
# [500]	validation-auc:0.873454
# [550]	validation-auc:0.874489
# [600]	validation-auc:0.875452
# [650]	validation-auc:0.876336
# [700]	validation-auc:0.877151
# [750]	validation-auc:0.877802
# [800]	validation-auc:0.878401
# [850]	validation-auc:0.878977
# [900]	validation-auc:0.879456
# [950]	validation-auc:0.879866
# [1000]	validation-auc:0.880283
# [1050]	validation-auc:0.88063
# [1100]	validation-auc:0.880982
# [1150]	validation-auc:0.881295
# [1200]	validation-auc:0.88163
# [1250]	validation-auc:0.881932
# [1300]	validation-auc:0.88222
# [1350]	validation-auc:0.882474
# [1400]	validation-auc:0.882751
# [1450]	validation-auc:0.882998
# [1500]	validation-auc:0.88321
# [1550]	validation-auc:0.883485
# [1600]	validation-auc:0.883688
# [1650]	validation-auc:0.88387
# [1700]	validation-auc:0.884062
# [1750]	validation-auc:0.884232
# [1800]	validation-auc:0.884404
# [1850]	validation-auc:0.884547
# [1900]	validation-auc:0.884694
# [1950]	validation-auc:0.884833
# [2000]	validation-auc:0.884963
# [2050]	validation-auc:0.88511
# [2100]	validation-auc:0.885261
# [2150]	validation-auc:0.885389
# [2200]	validation-auc:0.885513
# [2250]	validation-auc:0.885619
# [2300]	validation-auc:0.885727
# [2350]	validation-auc:0.885839
# [2400]	validation-auc:0.885935
# [2450]	validation-auc:0.886028
# [2500]	validation-auc:0.886142
# [2550]	validation-auc:0.886254
# [2600]	validation-auc:0.886347
# [2650]	validation-auc:0.88645
# [2700]	validation-auc:0.88652
# [2750]	validation-auc:0.886599
# [2800]	validation-auc:0.88667
# [2850]	validation-auc:0.886739
# [2900]	validation-auc:0.886813
# [2950]	validation-auc:0.886883
# [3000]	validation-auc:0.886959
# [3050]	validation-auc:0.887029
# [3100]	validation-auc:0.887109
# [3150]	validation-auc:0.887178
# [3200]	validation-auc:0.88725
# [3250]	validation-auc:0.887313
# [3300]	validation-auc:0.887383
# [3350]	validation-auc:0.887449
# Stopping. Best iteration:
# [3351]	validation-auc:0.88745
#
#
# max_depth = 5, eta = 0.02:
# [0]	validation-auc:0.821264
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.854456
# [100]	validation-auc:0.861874
# [150]	validation-auc:0.866726
# [200]	validation-auc:0.870465
# [250]	validation-auc:0.873236
# [300]	validation-auc:0.875277
# [350]	validation-auc:0.87695
# [400]	validation-auc:0.878244
# [450]	validation-auc:0.879233
# [500]	validation-auc:0.880092
# [550]	validation-auc:0.880846
# [600]	validation-auc:0.88139
# [650]	validation-auc:0.882017
# [700]	validation-auc:0.88253
# [750]	validation-auc:0.883006
# [800]	validation-auc:0.883528
# [850]	validation-auc:0.883926
# [900]	validation-auc:0.884247
# [950]	validation-auc:0.884525
# [1000]	validation-auc:0.884815
# [1050]	validation-auc:0.88504
# [1100]	validation-auc:0.885299
# [1150]	validation-auc:0.885559
# [1200]	validation-auc:0.88574
# [1250]	validation-auc:0.885952
# [1300]	validation-auc:0.886161
# [1350]	validation-auc:0.886296
# [1400]	validation-auc:0.886514
# [1450]	validation-auc:0.886687
# [1500]	validation-auc:0.88687
# [1550]	validation-auc:0.887021
# [1600]	validation-auc:0.887121
# [1650]	validation-auc:0.887246
# [1700]	validation-auc:0.887378
# [1750]	validation-auc:0.88747
# [1800]	validation-auc:0.887605
# [1850]	validation-auc:0.887688
# [1900]	validation-auc:0.887802
# [1950]	validation-auc:0.88791
# [2000]	validation-auc:0.887971
# Stopping. Best iteration:
# [1992]	validation-auc:0.887977
#
#
# max_depth = 5, eta = 0.05:
# [0]	validation-auc:0.821264
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.864224
# [100]	validation-auc:0.872944
# [150]	validation-auc:0.877438
# [200]	validation-auc:0.879821
# [250]	validation-auc:0.88151
# [300]	validation-auc:0.882779
# [350]	validation-auc:0.883735
# [400]	validation-auc:0.884575
# [450]	validation-auc:0.885208
# [500]	validation-auc:0.885777
# [550]	validation-auc:0.886159
# [600]	validation-auc:0.886502
# [650]	validation-auc:0.886799
# [700]	validation-auc:0.887079
# [750]	validation-auc:0.887281
# [800]	validation-auc:0.887502
# [850]	validation-auc:0.887663
# Stopping. Best iteration:
# [861]	validation-auc:0.88773
#
#
# max_depth = 5, eta = 0.1:
# [0]	validation-auc:0.821264
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.872981
# [100]	validation-auc:0.879924
# [150]	validation-auc:0.882981
# [200]	validation-auc:0.884572
# [250]	validation-auc:0.885657
# [300]	validation-auc:0.886277
# [350]	validation-auc:0.886837
# [400]	validation-auc:0.887248
# [450]	validation-auc:0.887721
# Stopping. Best iteration:
# [483]	validation-auc:0.888004
#
#
# max_depth = 5, eta = 0.2:
# [0]	validation-auc:0.821264
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.878792
# [100]	validation-auc:0.88335
# [150]	validation-auc:0.885149
# [200]	validation-auc:0.885919
# Stopping. Best iteration:
# [210]	validation-auc:0.885984
#
#
# max_depth = 6, eta = 0.01:
# [0]	validation-auc:0.831466
# Will train until validation-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation-auc:0.854188
#
#
# max_depth = 6, eta = 0.02:
# [0]	validation-auc:0.831466
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.860384
# [100]	validation-auc:0.866161
# [150]	validation-auc:0.870384
# [200]	validation-auc:0.874046
# [250]	validation-auc:0.876778
# [300]	validation-auc:0.878807
# [350]	validation-auc:0.88029
# [400]	validation-auc:0.881416
# [450]	validation-auc:0.882321
# [500]	validation-auc:0.883112
# [550]	validation-auc:0.883741
# [600]	validation-auc:0.884341
# [650]	validation-auc:0.884812
# [700]	validation-auc:0.885261
# [750]	validation-auc:0.885671
# [800]	validation-auc:0.886041
# [850]	validation-auc:0.886342
# [900]	validation-auc:0.886631
# [950]	validation-auc:0.886905
# [1000]	validation-auc:0.887094
# [1050]	validation-auc:0.88729
# [1100]	validation-auc:0.887516
# [1150]	validation-auc:0.887731
# [1200]	validation-auc:0.887908
# [1250]	validation-auc:0.888091
# [1300]	validation-auc:0.888245
# [1350]	validation-auc:0.888376
# [1400]	validation-auc:0.888494
# [1450]	validation-auc:0.888618
# [1500]	validation-auc:0.888755
# [1550]	validation-auc:0.888873
# Stopping. Best iteration:
# [1562]	validation-auc:0.888907
#
#
# max_depth = 6, eta = 0.05:
# [0]	validation-auc:0.831466
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.868188
# [100]	validation-auc:0.876737
# [150]	validation-auc:0.880931
# [200]	validation-auc:0.883136
# [250]	validation-auc:0.884479
# [300]	validation-auc:0.885577
# [350]	validation-auc:0.886284
# [400]	validation-auc:0.88691
# [450]	validation-auc:0.887338
# [500]	validation-auc:0.887782
# [550]	validation-auc:0.888117
# [600]	validation-auc:0.888399
# [650]	validation-auc:0.888633
# [700]	validation-auc:0.888844
# [750]	validation-auc:0.889036
# [800]	validation-auc:0.889169
# Stopping. Best iteration:
# [803]	validation-auc:0.889184
#
#
# max_depth = 6, eta = 0.1:
# [0]	validation-auc:0.831466
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.876632
# [100]	validation-auc:0.882579
# [150]	validation-auc:0.884788
# [200]	validation-auc:0.886292
# [250]	validation-auc:0.88701
# [300]	validation-auc:0.887669
# [350]	validation-auc:0.888132
# [400]	validation-auc:0.888426
# Stopping. Best iteration:
# [430]	validation-auc:0.888544
#
#
# max_depth = 6, eta = 0.2:
# [0]	validation-auc:0.831466
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.881483
# [100]	validation-auc:0.884977
# [150]	validation-auc:0.886252
# Stopping. Best iteration:
# [188]	validation-auc:0.886651
#
#
# max_depth = 7, eta = 0.01:
# [0]	validation-auc:0.83758
# Will train until validation-auc hasn't improved in 10 rounds.
# Stopping. Best iteration:
# [9]	validation-auc:0.859927
#
#
# max_depth = 7, eta = 0.02:
# [0]	validation-auc:0.83758
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.86476
# [100]	validation-auc:0.869971
# [150]	validation-auc:0.873911
# [200]	validation-auc:0.877166
# [250]	validation-auc:0.879749
# [300]	validation-auc:0.881618
# [350]	validation-auc:0.882917
# [400]	validation-auc:0.883954
# [450]	validation-auc:0.884682
# [500]	validation-auc:0.885338
# [550]	validation-auc:0.885904
# [600]	validation-auc:0.886405
# [650]	validation-auc:0.886805
# [700]	validation-auc:0.887191
# [750]	validation-auc:0.887556
# [800]	validation-auc:0.88785
# [850]	validation-auc:0.888128
# [900]	validation-auc:0.888351
# [950]	validation-auc:0.888547
# [1000]	validation-auc:0.888757
# [1050]	validation-auc:0.888911
# [1100]	validation-auc:0.889098
# [1150]	validation-auc:0.889254
# [1200]	validation-auc:0.8894
# [1250]	validation-auc:0.889507
# [1300]	validation-auc:0.889636
# [1350]	validation-auc:0.889731
# [1400]	validation-auc:0.88984
# [1450]	validation-auc:0.889941
# [1500]	validation-auc:0.890035
# [1550]	validation-auc:0.890149
# Stopping. Best iteration:
# [1589]	validation-auc:0.890183
#
#
# max_depth = 7, eta = 0.05:
# [0]	validation-auc:0.83758
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.872002
# [100]	validation-auc:0.879514
# [150]	validation-auc:0.883213
# [200]	validation-auc:0.885048
# [250]	validation-auc:0.886209
# [300]	validation-auc:0.887041
# [350]	validation-auc:0.887563
# [400]	validation-auc:0.88803
# [450]	validation-auc:0.888429
# [500]	validation-auc:0.888715
# [550]	validation-auc:0.889011
# Stopping. Best iteration:
# [572]	validation-auc:0.889108
#
#
# max_depth = 7, eta = 0.1:
# [0]	validation-auc:0.83758
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.878779
# [100]	validation-auc:0.884223
# [150]	validation-auc:0.886396
# [200]	validation-auc:0.887396
# [250]	validation-auc:0.887975
# [300]	validation-auc:0.888465
# [350]	validation-auc:0.888728
# Stopping. Best iteration:
# [349]	validation-auc:0.888754
#
#
# max_depth = 7, eta = 0.2:
# [0]	validation-auc:0.83758
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.882796
# [100]	validation-auc:0.885496
# Stopping. Best iteration:
# [123]	validation-auc:0.885905

# %%
for t in validation_auc_1.most_common():
    print(t)
# Out:
# ((7, 0.02), 0.890183)
# ((6, 0.05), 0.889184)
# ((7, 0.05), 0.889108)
# ((6, 0.02), 0.888907)
# ((7, 0.1), 0.888754)
# ((6, 0.1), 0.888544)
# ((5, 0.1), 0.888004)
# ((5, 0.02), 0.887977)
# ((5, 0.05), 0.88773)
# ((5, 0.01), 0.88745)
# ((6, 0.2), 0.886651)
# ((4, 0.1), 0.886597)
# ((4, 0.05), 0.88649)
# ((4, 0.02), 0.886381)
# ((5, 0.2), 0.885984)
# ((4, 0.2), 0.885982)
# ((7, 0.2), 0.885905)
# ((7, 0.01), 0.859927)
# ((6, 0.01), 0.854188)
# ((4, 0.01), 0.841674)

# %% [markdown]
# #### (2) Grid Search for min_child_weight (along with max_depth)

# %%
md1 = 6
grid_2 = [(md1+i,mcw) for i in [-1,0,1] for mcw in [3,5]]
validation_auc_2 = Counter()
for md,mcw in grid_2:
    print("max_depth = {0}, min_child_weight = {1}:".format(md,mcw))
    params = {'max_depth': md, 'eta': 0.05, 'min_child_weight': mcw, 'colsample_bytree': 0.8, 
              'subsample': 0.8, 
              'objective': 'binary:logistic', 'eval_metric': ['auc'],
              'seed': 12345}
    evals_result = {}
    xgb_model = xgb.train(params = params, dtrain = dtrain_train, num_boost_round = int(5e3), evals = [(dtrain_val, 'validation')],
                          early_stopping_rounds = 10,
                          evals_result = evals_result,
                          verbose_eval = 50)
    validation_auc_2[(md,mcw)] = np.max(evals_result['validation']['auc'])
    print("")
# Out:
# max_depth = 5, min_child_weight = 3:
# [0]	validation-auc:0.821264
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.864234
# [100]	validation-auc:0.873057
# [150]	validation-auc:0.877574
# [200]	validation-auc:0.880207
# [250]	validation-auc:0.881813
# [300]	validation-auc:0.883046
# [350]	validation-auc:0.884048
# [400]	validation-auc:0.884949
# [450]	validation-auc:0.885536
# [500]	validation-auc:0.886033
# [550]	validation-auc:0.886443
# [600]	validation-auc:0.886698
# [650]	validation-auc:0.886868
# [700]	validation-auc:0.887221
# [750]	validation-auc:0.887473
# [800]	validation-auc:0.887691
# [850]	validation-auc:0.887913
# [900]	validation-auc:0.888091
# [950]	validation-auc:0.888191
# [1000]	validation-auc:0.888355
# Stopping. Best iteration:
# [1037]	validation-auc:0.888416
#
#
# max_depth = 5, min_child_weight = 5:
# [0]	validation-auc:0.821264
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.864218
# [100]	validation-auc:0.873098
# [150]	validation-auc:0.877427
# [200]	validation-auc:0.879999
# [250]	validation-auc:0.881605
# [300]	validation-auc:0.882892
# [350]	validation-auc:0.883729
# [400]	validation-auc:0.884656
# [450]	validation-auc:0.885391
# [500]	validation-auc:0.885943
# [550]	validation-auc:0.886321
# [600]	validation-auc:0.886653
# [650]	validation-auc:0.886874
# [700]	validation-auc:0.887196
# [750]	validation-auc:0.887394
# [800]	validation-auc:0.887638
# [850]	validation-auc:0.887852
# [900]	validation-auc:0.888041
# [950]	validation-auc:0.888159
# [1000]	validation-auc:0.888324
# Stopping. Best iteration:
# [1035]	validation-auc:0.888406
#
#
# max_depth = 6, min_child_weight = 3:
# [0]	validation-auc:0.831463
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.868153
# [100]	validation-auc:0.876705
# [150]	validation-auc:0.880831
# [200]	validation-auc:0.88284
# [250]	validation-auc:0.884223
# [300]	validation-auc:0.885362
# [350]	validation-auc:0.886066
# [400]	validation-auc:0.886747
# [450]	validation-auc:0.887229
# [500]	validation-auc:0.887763
# [550]	validation-auc:0.88812
# [600]	validation-auc:0.888348
# [650]	validation-auc:0.888584
# [700]	validation-auc:0.888806
# Stopping. Best iteration:
# [698]	validation-auc:0.888811
#
#
# max_depth = 6, min_child_weight = 5:
# [0]	validation-auc:0.831465
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.868351
# [100]	validation-auc:0.876632
# [150]	validation-auc:0.880639
# [200]	validation-auc:0.882817
# [250]	validation-auc:0.884355
# [300]	validation-auc:0.885322
# [350]	validation-auc:0.886082
# [400]	validation-auc:0.886693
# [450]	validation-auc:0.88717
# [500]	validation-auc:0.887645
# [550]	validation-auc:0.887922
# [600]	validation-auc:0.888183
# [650]	validation-auc:0.888389
# [700]	validation-auc:0.88858
# [750]	validation-auc:0.888776
# [800]	validation-auc:0.888881
# Stopping. Best iteration:
# [813]	validation-auc:0.888946
#
#
# max_depth = 7, min_child_weight = 3:
# [0]	validation-auc:0.837536
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.871605
# [100]	validation-auc:0.879236
# [150]	validation-auc:0.882835
# [200]	validation-auc:0.884679
# [250]	validation-auc:0.886009
# [300]	validation-auc:0.886914
# [350]	validation-auc:0.887631
# [400]	validation-auc:0.888119
# [450]	validation-auc:0.888442
# [500]	validation-auc:0.888773
# [550]	validation-auc:0.889029
# Stopping. Best iteration:
# [550]	validation-auc:0.889029
#
#
# max_depth = 7, min_child_weight = 5:
# [0]	validation-auc:0.837639
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.871827
# [100]	validation-auc:0.87927
# [150]	validation-auc:0.883125
# [200]	validation-auc:0.88499
# [250]	validation-auc:0.886175
# [300]	validation-auc:0.886925
# [350]	validation-auc:0.887517
# [400]	validation-auc:0.88803
# [450]	validation-auc:0.888369
# [500]	validation-auc:0.88875
# [550]	validation-auc:0.889066
# [600]	validation-auc:0.889289
# [650]	validation-auc:0.889476
# Stopping. Best iteration:
# [689]	validation-auc:0.889633

# %%
for t in validation_auc_2.most_common():
    print(t)
# Out:
# ((7, 5), 0.889633)
# ((7, 3), 0.889029)
# ((6, 5), 0.888946)
# ((6, 3), 0.888811)
# ((5, 3), 0.888416)
# ((5, 5), 0.888406)

# %% [markdown]
# #### (3) Grid Search for colsample_by_tree

# %%
grid_3 = [0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
validation_auc_3 = Counter()
for cbt in grid_3:
    print("colsample_by_tree = {}:".format(cbt))
    params = {'max_depth': 7, 'eta': 0.02, 'min_child_weight': 5, 'colsample_bytree': cbt, 
              'subsample': 0.8, 
              'objective': 'binary:logistic', 'eval_metric': ['auc'],
              'seed': 12345}
    evals_result = {}
    xgb_model = xgb.train(params = params, dtrain = dtrain_train, num_boost_round = int(5e3), evals = [(dtrain_val, 'validation')],
                          early_stopping_rounds = 10,
                          evals_result = evals_result,
                          verbose_eval = 50)
    validation_auc_3[cbt] = np.max(evals_result['validation']['auc'])
    print("")
# Out:
# colsample_by_tree = 0.5:
# [0]	validation-auc:0.829477
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.86593
# [100]	validation-auc:0.870276
# [150]	validation-auc:0.874362
# [200]	validation-auc:0.87727
# [250]	validation-auc:0.879728
# [300]	validation-auc:0.881426
# [350]	validation-auc:0.88278
# [400]	validation-auc:0.883865
# [450]	validation-auc:0.884579
# [500]	validation-auc:0.885285
# [550]	validation-auc:0.885771
# [600]	validation-auc:0.886248
# [650]	validation-auc:0.886628
# [700]	validation-auc:0.886993
# [750]	validation-auc:0.887259
# [800]	validation-auc:0.887571
# [850]	validation-auc:0.887771
# [900]	validation-auc:0.888028
# [950]	validation-auc:0.888223
# [1000]	validation-auc:0.888399
# [1050]	validation-auc:0.888537
# [1100]	validation-auc:0.888684
# [1150]	validation-auc:0.888813
# [1200]	validation-auc:0.888937
# [1250]	validation-auc:0.889055
# [1300]	validation-auc:0.889178
# [1350]	validation-auc:0.889258
# [1400]	validation-auc:0.889378
# [1450]	validation-auc:0.889514
# [1500]	validation-auc:0.889611
# [1550]	validation-auc:0.889743
# [1600]	validation-auc:0.889824
# [1650]	validation-auc:0.889897
# [1700]	validation-auc:0.889974
# Stopping. Best iteration:
# [1716]	validation-auc:0.890015
#
#
# colsample_by_tree = 0.55:
# [0]	validation-auc:0.828853
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.865835
# [100]	validation-auc:0.870249
# [150]	validation-auc:0.874125
# [200]	validation-auc:0.877152
# [250]	validation-auc:0.879692
# [300]	validation-auc:0.881507
# [350]	validation-auc:0.882781
# [400]	validation-auc:0.883746
# [450]	validation-auc:0.884485
# [500]	validation-auc:0.885197
# [550]	validation-auc:0.885711
# [600]	validation-auc:0.886193
# [650]	validation-auc:0.886583
# [700]	validation-auc:0.886942
# [750]	validation-auc:0.887243
# [800]	validation-auc:0.887559
# [850]	validation-auc:0.887823
# [900]	validation-auc:0.888039
# [950]	validation-auc:0.888241
# [1000]	validation-auc:0.888421
# [1050]	validation-auc:0.888607
# [1100]	validation-auc:0.888768
# [1150]	validation-auc:0.888897
# [1200]	validation-auc:0.88901
# [1250]	validation-auc:0.889135
# Stopping. Best iteration:
# [1274]	validation-auc:0.889199
#
#
# colsample_by_tree = 0.6:
# [0]	validation-auc:0.829271
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.865542
# [100]	validation-auc:0.870339
# [150]	validation-auc:0.874276
# [200]	validation-auc:0.8773
# [250]	validation-auc:0.879899
# [300]	validation-auc:0.881706
# [350]	validation-auc:0.882951
# [400]	validation-auc:0.883919
# [450]	validation-auc:0.884696
# [500]	validation-auc:0.885396
# [550]	validation-auc:0.885907
# [600]	validation-auc:0.886331
# [650]	validation-auc:0.886698
# [700]	validation-auc:0.88703
# [750]	validation-auc:0.887302
# [800]	validation-auc:0.887575
# [850]	validation-auc:0.88781
# [900]	validation-auc:0.888067
# [950]	validation-auc:0.888291
# [1000]	validation-auc:0.888488
# [1050]	validation-auc:0.888623
# [1100]	validation-auc:0.888772
# [1150]	validation-auc:0.888903
# [1200]	validation-auc:0.889011
# [1250]	validation-auc:0.889119
# [1300]	validation-auc:0.889252
# Stopping. Best iteration:
# [1330]	validation-auc:0.889331
#
#
# colsample_by_tree = 0.65:
# [0]	validation-auc:0.829243
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.865275
# [100]	validation-auc:0.870163
# [150]	validation-auc:0.874091
# [200]	validation-auc:0.87718
# [250]	validation-auc:0.879784
# [300]	validation-auc:0.881603
# [350]	validation-auc:0.882883
# [400]	validation-auc:0.883861
# [450]	validation-auc:0.884596
# [500]	validation-auc:0.885265
# [550]	validation-auc:0.885771
# [600]	validation-auc:0.886275
# [650]	validation-auc:0.886673
# [700]	validation-auc:0.88702
# [750]	validation-auc:0.887363
# [800]	validation-auc:0.887648
# [850]	validation-auc:0.887873
# [900]	validation-auc:0.888092
# [950]	validation-auc:0.888296
# [1000]	validation-auc:0.888449
# [1050]	validation-auc:0.888596
# [1100]	validation-auc:0.888726
# [1150]	validation-auc:0.888836
# [1200]	validation-auc:0.888969
# [1250]	validation-auc:0.8891
# [1300]	validation-auc:0.889233
# [1350]	validation-auc:0.889311
# [1400]	validation-auc:0.889399
# [1450]	validation-auc:0.889487
# [1500]	validation-auc:0.889583
# [1550]	validation-auc:0.88971
# [1600]	validation-auc:0.889773
# Stopping. Best iteration:
# [1594]	validation-auc:0.889779
#
#
# colsample_by_tree = 0.7:
# [0]	validation-auc:0.831911
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.865393
# [100]	validation-auc:0.870254
# [150]	validation-auc:0.873996
# [200]	validation-auc:0.877146
# [250]	validation-auc:0.879619
# [300]	validation-auc:0.881528
# [350]	validation-auc:0.882793
# [400]	validation-auc:0.883745
# [450]	validation-auc:0.884506
# [500]	validation-auc:0.885183
# [550]	validation-auc:0.885726
# [600]	validation-auc:0.886167
# [650]	validation-auc:0.886599
# [700]	validation-auc:0.886946
# [750]	validation-auc:0.887274
# [800]	validation-auc:0.887601
# [850]	validation-auc:0.887883
# [900]	validation-auc:0.888094
# [950]	validation-auc:0.888298
# [1000]	validation-auc:0.888484
# [1050]	validation-auc:0.88867
# [1100]	validation-auc:0.888801
# [1150]	validation-auc:0.888964
# [1200]	validation-auc:0.889087
# [1250]	validation-auc:0.889246
# [1300]	validation-auc:0.889392
# [1350]	validation-auc:0.889478
# [1400]	validation-auc:0.889588
# [1450]	validation-auc:0.889689
# [1500]	validation-auc:0.889819
# [1550]	validation-auc:0.889922
# [1600]	validation-auc:0.889974
# Stopping. Best iteration:
# [1592]	validation-auc:0.889984
#
#
# colsample_by_tree = 0.75:
# [0]	validation-auc:0.836803
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.865282
# [100]	validation-auc:0.870262
# [150]	validation-auc:0.873942
# [200]	validation-auc:0.877125
# [250]	validation-auc:0.87972
# [300]	validation-auc:0.881516
# [350]	validation-auc:0.882796
# [400]	validation-auc:0.883826
# [450]	validation-auc:0.884646
# [500]	validation-auc:0.885249
# [550]	validation-auc:0.885837
# [600]	validation-auc:0.886268
# [650]	validation-auc:0.88667
# [700]	validation-auc:0.887059
# [750]	validation-auc:0.887444
# [800]	validation-auc:0.887752
# [850]	validation-auc:0.888013
# [900]	validation-auc:0.888212
# [950]	validation-auc:0.888414
# [1000]	validation-auc:0.888593
# [1050]	validation-auc:0.888728
# [1100]	validation-auc:0.888915
# [1150]	validation-auc:0.889068
# [1200]	validation-auc:0.889174
# [1250]	validation-auc:0.889314
# [1300]	validation-auc:0.889435
# [1350]	validation-auc:0.889538
# Stopping. Best iteration:
# [1371]	validation-auc:0.889585
#
#
# colsample_by_tree = 0.8:
# [0]	validation-auc:0.837639
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.864794
# [100]	validation-auc:0.870054
# [150]	validation-auc:0.873848
# [200]	validation-auc:0.877111
# [250]	validation-auc:0.879675
# [300]	validation-auc:0.881561
# [350]	validation-auc:0.882798
# [400]	validation-auc:0.88383
# [450]	validation-auc:0.884583
# [500]	validation-auc:0.885262
# [550]	validation-auc:0.885861
# [600]	validation-auc:0.886306
# [650]	validation-auc:0.886706
# [700]	validation-auc:0.887087
# [750]	validation-auc:0.887428
# [800]	validation-auc:0.88777
# [850]	validation-auc:0.888021
# [900]	validation-auc:0.888222
# [950]	validation-auc:0.888465
# [1000]	validation-auc:0.888667
# [1050]	validation-auc:0.888807
# [1100]	validation-auc:0.888925
# [1150]	validation-auc:0.889084
# Stopping. Best iteration:
# [1178]	validation-auc:0.889189
#
#
# colsample_by_tree = 0.85:
# [0]	validation-auc:0.837639
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.864757
# [100]	validation-auc:0.86995
# [150]	validation-auc:0.873796
# [200]	validation-auc:0.877154
# [250]	validation-auc:0.879693
# [300]	validation-auc:0.881518
# [350]	validation-auc:0.882854
# [400]	validation-auc:0.883816
# [450]	validation-auc:0.884597
# [500]	validation-auc:0.885281
# [550]	validation-auc:0.885788
# [600]	validation-auc:0.886221
# [650]	validation-auc:0.886598
# [700]	validation-auc:0.886963
# [750]	validation-auc:0.887302
# [800]	validation-auc:0.887606
# [850]	validation-auc:0.88785
# [900]	validation-auc:0.888074
# [950]	validation-auc:0.888317
# [1000]	validation-auc:0.888482
# [1050]	validation-auc:0.888608
# [1100]	validation-auc:0.888763
# [1150]	validation-auc:0.888933
# [1200]	validation-auc:0.889058
# [1250]	validation-auc:0.889188
# [1300]	validation-auc:0.889307
# [1350]	validation-auc:0.889382
# [1400]	validation-auc:0.889526
# [1450]	validation-auc:0.889634
# [1500]	validation-auc:0.889748
# [1550]	validation-auc:0.889834
# [1600]	validation-auc:0.889883
# Stopping. Best iteration:
# [1634]	validation-auc:0.889928
#
#
# colsample_by_tree = 0.9:
# [0]	validation-auc:0.840427
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.86446
# [100]	validation-auc:0.870069
# [150]	validation-auc:0.873935
# [200]	validation-auc:0.877215
# [250]	validation-auc:0.879769
# [300]	validation-auc:0.881581
# [350]	validation-auc:0.882814
# [400]	validation-auc:0.88378
# [450]	validation-auc:0.884537
# [500]	validation-auc:0.885151
# [550]	validation-auc:0.885715
# [600]	validation-auc:0.886221
# [650]	validation-auc:0.886603
# [700]	validation-auc:0.887027
# [750]	validation-auc:0.887347
# [800]	validation-auc:0.887673
# [850]	validation-auc:0.887946
# [900]	validation-auc:0.888184
# [950]	validation-auc:0.888369
# [1000]	validation-auc:0.88856
# [1050]	validation-auc:0.888704
# [1100]	validation-auc:0.888847
# [1150]	validation-auc:0.889003
# [1200]	validation-auc:0.889123
# [1250]	validation-auc:0.889273
# [1300]	validation-auc:0.889418
# [1350]	validation-auc:0.889502
# [1400]	validation-auc:0.88961
# [1450]	validation-auc:0.889684
# [1500]	validation-auc:0.889769
# [1550]	validation-auc:0.889862
# Stopping. Best iteration:
# [1550]	validation-auc:0.889862

# %%
validation_auc_3.most_common()
# Out:
# [(0.5, 0.890015),
#  (0.7, 0.889984),
#  (0.85, 0.889928),
#  (0.9, 0.889862),
#  (0.65, 0.889779),
#  (0.75, 0.889585),
#  (0.6, 0.889331),
#  (0.55, 0.889199),
#  (0.8, 0.889189)]

# %% [markdown]
# #### (4) Finally select the opitmal num_boost_round

# %%
params = {'max_depth': 7, 'eta': 0.02, 'min_child_weight': 5, 'colsample_bytree': 0.7, 
          'subsample': 0.8, 
          'objective': 'binary:logistic', 'eval_metric': ['auc'],
          'seed': 12345}
evals_result = {}
xgb_model = xgb.train(params = params, dtrain = dtrain_train, num_boost_round = int(5e3), evals = [(dtrain_val, 'validation')],
                      early_stopping_rounds = 10,
                      evals_result = evals_result,
                      verbose_eval = 50)
optimal_num_boost_round = np.argmax(evals_result['validation']['auc'])
print("")
print(optimal_num_boost_round)
# Out:
# [0]	validation-auc:0.831911
# Will train until validation-auc hasn't improved in 10 rounds.
# [50]	validation-auc:0.865393
# [100]	validation-auc:0.870254
# [150]	validation-auc:0.873996
# [200]	validation-auc:0.877146
# [250]	validation-auc:0.879619
# [300]	validation-auc:0.881528
# [350]	validation-auc:0.882793
# [400]	validation-auc:0.883745
# [450]	validation-auc:0.884506
# [500]	validation-auc:0.885183
# [550]	validation-auc:0.885726
# [600]	validation-auc:0.886167
# [650]	validation-auc:0.886599
# [700]	validation-auc:0.886946
# [750]	validation-auc:0.887274
# [800]	validation-auc:0.887601
# [850]	validation-auc:0.887883
# [900]	validation-auc:0.888094
# [950]	validation-auc:0.888298
# [1000]	validation-auc:0.888484
# [1050]	validation-auc:0.88867
# [1100]	validation-auc:0.888801
# [1150]	validation-auc:0.888964
# [1200]	validation-auc:0.889087
# [1250]	validation-auc:0.889246
# [1300]	validation-auc:0.889392
# [1350]	validation-auc:0.889478
# [1400]	validation-auc:0.889588
# [1450]	validation-auc:0.889689
# [1500]	validation-auc:0.889819
# [1550]	validation-auc:0.889922
# [1600]	validation-auc:0.889974
# Stopping. Best iteration:
# [1592]	validation-auc:0.889984
#
#
# 1592

# %% [markdown]
# #### (5) Train the final xgb model and make predictions for observations in the test set

# %%
# specify parameters via map
params = {'max_depth': 7, 'eta': 0.02, 'min_child_weight': 5, 'colsample_bytree': 0.7, 
          'subsample': 0.8, 
          'objective': 'binary:logistic', 'eval_metric': ['auc'],
          'seed': 12345}
final_xgb_model = xgb.train(params = params, dtrain = dtrain, num_boost_round = optimal_num_boost_round)
# make prediction for observations in the test set
y_test_pred = final_xgb_model.predict(dtest)

# %%
print("XGBoost:")
print("AUC = {}".format(round(roc_auc_score(dtest.get_label(), y_test_pred), 4)))
# Out:
# XGBoost:
# AUC = 0.8946

# %%
# save the model object and predicted scores on the validation sample to local disk
# pickle.dump(final_xgb_model, open(results_dir + "xgb.p", "wb"))
pickle.dump(list(y_test_pred), open(results_dir + "y_test_pred_xgb.p", "wb"))

# %%
feature_importance = pd.DataFrame(list(final_xgb_model.get_fscore().items()), columns=['feature','importance']).sort_values('importance', ascending=False)
feature_importance.loc[:, 'importance'] = feature_importance.loc[:, 'importance'] / sum(feature_importance.loc[:, 'importance'])
yy = feature_importance.loc[:, 'importance'].iloc[:20]
xx = feature_importance.loc[:, 'feature'].iloc[:20]

# %%
fig = plt.figure(figsize=(12,9))
plt.bar(list(range(20)), yy, width=0.75, color = "orange")
plt.xticks(list(range(20)), xx, rotation = 'vertical', fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Predictor", fontsize=16, color="gray")
plt.ylabel("Feature Importance", fontsize=16, color="gray")
plt.savefig(results_dir + "XGBoost_variable_importance.png", bbox_inches='tight')
plt.show()

# %%
def find_optimal_threshold(p,r,t):
    to_drop = np.union1d(np.where(pd.isnull(p[:-1]) == True)[0], np.where(pd.isnull(r[:-1]) == True)[0])
    to_drop = np.union1d(to_drop, np.where(pd.isnull(t) == True)[0])
    to_keep = np.setdiff1d(np.array(list(range(len(p)-1))), to_drop)
    p,r,t = p[to_keep],r[to_keep],t[to_keep]
    f1 = 2*p*r/(p+r)
    best_t = t[np.argmax(f1)]
    best_t
    return best_t

def cross_validation(train, xgb_params, nbr):
    threshold_list = []
    auc_list = []
    k_fold =  StratifiedKFold(n_splits = 10, random_state = 12345, shuffle=True)
    for train_indices, test_indices in k_fold.split(train, train.grad_6years):
        train_part = train.iloc[train_indices,:]
        test_part = train.iloc[test_indices,:]
        train_part_new, test_part_new = impute(train_part, test_part)
        X_1 = train_part_new.loc[:,predictors]
        y_1 = train_part_new.grad_6years
        X_2 = test_part_new.loc[:,predictors]
        y_2 = test_part_new.grad_6years
        dtrain_cv = xgb.DMatrix(X_1,y_1)
        dtest_cv = xgb.DMatrix(X_2,y_2)
        xgb_cv_model = xgb.train(params=xgb_params, dtrain=dtrain_cv, num_boost_round = nbr)
        y_2_pred = xgb_cv_model.predict(dtest_cv)
        p,r,t = precision_recall_curve(y_2, y_2_pred)
        auc = roc_auc_score(y_2, y_2_pred)
        threshold_list.append(find_optimal_threshold(p,r,t))
        auc_list.append(auc)
    print(np.mean(auc_list), np.std(auc_list, ddof=1))
    return gmean(threshold_list)

# %%
final_params = {'max_depth': 7, 'eta': 0.02, 'min_child_weight': 5, 'colsample_bytree': 0.7, 
                'subsample': 0.8, 
                'objective': 'binary:logistic', 'eval_metric': ['auc'],
                'seed': 12345}
best_threshold = cross_validation(train_df, final_params, optimal_num_boost_round)
# Out:
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\ys8mz\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 0.8909754978903761 0.0018665774186206706

# %%
best_threshold
# Out:
# 0.38798702

# %%
def create_confusion_matrix(y_test_pred, threshold, fname):
    cm_arr = confusion_matrix(y_test, np.where(y_test_pred > threshold, 1, 0))
    cm_df = pd.DataFrame(cm_arr, columns=['Pred_0','Pred_1'], index=['Real_0', 'Real_1'])
    cm_df.loc[:,''] = cm_df.sum(axis=1)
    cm_df.loc['',:] = cm_df.sum(axis=0)
    print(cm_df)
    print("")
    p1 = cm_df.iloc[1,1]/cm_df.iloc[2,1]
    r1 = cm_df.iloc[1,1]/cm_df.iloc[1,2]
    p0 = cm_df.iloc[0,0]/cm_df.iloc[2,0]
    r0 = cm_df.iloc[0,0]/cm_df.iloc[0,2]    
    print("F1 score = {}".format(round(2*p1*r1/(p1+r1),4)))    
    cm_df.to_csv(results_dir + fname + ".csv")
    return p1,r1,p0,r0,round(2*p1*r1/(p1+r1),4)

# %%
print("F1 threshold = {}:\n".format(str(round(best_threshold,3))))
pr_xgb = create_confusion_matrix(y_test_pred, best_threshold, "XGBoost_cm1")
# Out:
# F1 threshold = 0.388:
#
#          Pred_0   Pred_1
# Real_0  18693.0   3115.0  21808.0
# Real_1   2510.0   8797.0  11307.0
#         21203.0  11912.0  33115.0
#
# F1 score = 0.7577

# %%
num_of_0 = int(round((1-np.mean(train_df.grad_6years))*len(y_test)))
y_test_pred_binary = np.ones(len(y_test))
y_test_pred_binary[np.argsort(y_test_pred)[:num_of_0]] = 0
alternative_threshold = y_test_pred[np.argsort(y_test_pred)[num_of_0]]
print("Alternative threshold = {}:\n".format(str(round(alternative_threshold,3))))
pr2_xgb = create_confusion_matrix(y_test_pred_binary, best_threshold, "XGBoost_cm2")
# Out:
# Alternative threshold = 0.421:
#
#          Pred_0   Pred_1
# Real_0  19043.0   2765.0  21808.0
# Real_1   2746.0   8561.0  11307.0
#         21789.0  11326.0  33115.0
#
# F1 score = 0.7565

# %%
precision_recall_df = pd.DataFrame([(best_threshold,)+pr_xgb,(alternative_threshold,)+pr2_xgb]).round(4)
precision_recall_df.index = ['F1','Same_Graduation_Rate']
precision_recall_df.columns = ['threshold','precision_1','recall_1','precision_0','recall_0','f1_score']
precision_recall_df.to_csv(results_dir + "XGBoost_precision_recall.csv", index=True)

# %%
eval_results_5 = []
for sg in sgs:
    eval_results_5.append(eval_subgroup(y_test_pred,sg,best_threshold))
eval_5_df = pd.DataFrame(eval_results_5, columns = ['subgroup', 'N', 'deg_compl_rate_real', 'deg_compl_rate_pred', 'avg_pred_score', 'c-statistic', 'precision_1', 'recall_1', 'precision_0', 'recall_0'])
eval_5_df.to_csv(results_dir + "XGBoost_subgroups.csv", index=False)

# %% [markdown]
# #### Reorganize files of key evaluation metrics for the five models fitted on the training sample without NSC predictors: OLS, Logit, RF, XGBoost, CoxPH

# %%
# Key evaluation metrics used to generate Appendix Figure A32 of the paper
cstat = [0.8747,0.8701,0.8729,0.877,0.8946]
m_dict = {'Logit': 'LR1', 'OLS': 'OLS',
          'RF': 'RF', 'XGBoost': 'XGBoost',
          'CoxPH': 'Cox'}
m_list = ['Logit', 'OLS', 'CoxPH', 'RF', 'XGBoost']
summary = []
for c,m in zip(cstat,m_list):
    summary.append((m,c)+tuple(pd.read_csv(results_dir + "\\{}_precision_recall.csv".format(m_dict[m])).iloc[0,1:]))
summary_df = pd.DataFrame(summary, columns=['model','c-statistic','threshold','precision_1','recall_1',
                                            'precision_0','recall_0','f1_score_1'])
summary_df.loc[:,'f1_score_0'] = 2*summary_df.precision_0*summary_df.recall_0/(summary_df.precision_0+summary_df.recall_0)
summary_df.loc[:,'f1_score_0'] = summary_df.loc[:,'f1_score_0'].apply(lambda x: round(x,4))
summary_df.to_csv(results_dir + "cleaned_results\\main_eval_metrics.csv", index=False)
